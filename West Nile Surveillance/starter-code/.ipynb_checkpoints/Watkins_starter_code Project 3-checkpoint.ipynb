# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary classifier.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title, and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use a random forest classifier, as well as another classifier of your choice; either logistic regression, SVM, or KNN.
#
# - **Question**: Why would we want this to be a classification problem?
# - **Answer**: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Set up a request (using requests) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)
# The URL here has many query parameters
# - q for the job search
# - This is followed by "+20,000" to return results with salaries (or expected salaries >$20,000)
# - l for a location
# - start for what result number to start on

# %%
URL = "https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York"
base_url = "https://www.indeed.com/jobs?q=data+scientist&l="

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import urllib
from urllib import urlopen 
import re

# %%
# visit that url, and grab the html of said page
html = urllib.urlopen(URL).read()

# we need to convert this into a soup object
soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")

# %% [markdown]
# Let's look at one result more closely. A single result looks like
# ```JSON
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&campaignid=serp-linkcompanyname&fromjk=2480d203f7e97210&jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```

# %%
# 'find' method returns the first matching Tag (and everything inside of it)
soup.find(name='body')
soup.find(name='h1')
# Out:
# <h1><font size="+1">data scientist $20,000 jobs in New York, NY</font></h1>

# %%
# Tags allow you to access the 'inside text'
soup.find(name='h1').text
# Out:
# u'data scientist $20,000 jobs in New York, NY'

# %% [markdown]
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a nobr element inside of a td element with class='snip.
# - The title of a job is in a link with class set to jobtitle and a data-tn-element="jobTitle.
# - The location is set in a span with class='location'.
# - The company is set in a span with class='company'.

# %% [markdown]
# ## Write 4 functions to extract each item: location, company, job, and salary.¶
# Example
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
# ##### - Make sure these functions are robust and can handle cases where the data/field may not be available.
# >- Remember to check if a field is empty or None for attempting to call methods on it
# >- Remember to use try/except if you anticipate errors.
#
# - **Test** the functions on the results above and simple examples

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def extract_location_from_result(result):
    try:
        item = result.find(name='span', attrs={'class': 'location'}).text
    except: 
        item= None
    return item

# %%
def extract_company_from_result(result):
    try:
        item = result.find('span', {'class': 'company'}).text
        item = item.replace('\n','')
        while item[0] == ' ':
            item = item[1:]
    except: 
        item= None
    return item

# %%
def extract_job(result):
    item = result.find('a', attrs={"class":"turnstileLink"}).attrs['title']
    return item
    
extract_job(soup)
# Out:
# u'Medical Lab Scientist - On Call'

# %%
def extract_salary_from_result(result):
    try:
        item = result.find('td', {'class': 'snip'}).find('nobr').text
    except: 
        item= None
    return item 

extract_salary_from_result(soup)




#nobr 

# class="jobtitle turnstileLink"

# %%
#cleans data so that we have less u'/n/n presence 
def clean_one(row, job):
    for data in soup.find_all(name='td', attrs={'id':'resultsCol'}):
        bra = data.find_all(name='div', attrs={'class': row})
        for row in bra:
            company = row.find(class_ = "company").get_text()
            location = row.find(class_ = "location").get_text()
            title = row.find(class_ = job).get_text()
#             salary = row.find_all(name = 'td', attrs={'class':'snip'})
            print "title = "+title
            print "company ="+company
            print "location = "+location
#             print extract_salary_from_result
clean_one(' row result', 'jobtitle')
#clean_one(' row sjlast result', 'jobtitle')
# Out:
# title =
# Medical Lab Scientist - On Call
#
# company =
#
#
#         The Vancouver Clinic
#
# location = Salmon Creek, WA
# title =
# Director of training and clinical operations
#
# company =
#
#     Portland Psychotherapy Clinic, Research, & Trainin...
#
# location = Portland, OR
# title =
# Data Scientist Internship - Deep Learning
#
# company =
#
#
#         Cambia Health
#
# location = Portland, OR
# title =
# Data Scientist - Machine Learning, NLP
#
# company =
#
#
#         WSI Nationwide
#
# location = Portland, OR
# title =
# Statistician - Sustainable Business Innovation
#
# company =
#
#
#         24 Seven
#
# location = Beaverton, OR
# title =
# Laboratory Quality Manager
#
# company =
#
#     Cannabis Testing Facility
#
# location = Portland, OR
# title =
# Senior Lead Mechanical Engineer
#
# company =
#
#     LightSource Consulting
#
# location = Portland, OR 97205 (Northwest area)
# title =
# D2i Development Initiator/Development Coordinator
#
# company =
#
#
#         FEI Company
#
# location = Hillsboro, OR 97124
# title =
# Sr .NET Software Engineer
#
# company =
#
#
#         VanderHouwen
#
# location = Portland, OR

# %%
#shows the value of .strip 
results = soup.find_all('div', attrs={'data-tn-component': 'organicJob'})

for x in results:
    company = x.find('span', attrs={"itemprop":"name"})
    print 'company:', company.text.strip()

    job = x.find('a', attrs={'data-tn-element': "jobTitle"})
    print 'job:', job.text.strip()

    salary = x.find('nobr')
    if salary:
        print 'salary:', salary.text.strip()
# Out:
# company: The Vancouver Clinic
# job: Medical Lab Scientist - On Call
# company: Portland Psychotherapy Clinic, Research, & Trainin...
# job: Director of training and clinical operations
# company: Cambia Health
# job: Data Scientist Internship - Deep Learning
# company: WSI Nationwide
# job: Data Scientist - Machine Learning, NLP
# salary: $120,000 - $165,000 a year
# company: 24 Seven
# job: Statistician - Sustainable Business Innovation
# company: Cannabis Testing Facility
# job: Laboratory Quality Manager
# salary: $18 - $22 an hour
# company: LightSource Consulting
# job: Senior Lead Mechanical Engineer
# company: FEI Company
# job: D2i Development Initiator/Development Coordinator
# company: VanderHouwen
# job: Sr .NET Software Engineer
# company: Cambia Health
# job: Data Scientist

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the l=New+York and the start=10. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).
# ##### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
YOUR_CITY = ''

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Seattle', 
    'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas', 'Pittsburgh', 
    'Portland', 'Phoenix', 'Denver', 'Houston', 'Miami', YOUR_CITY]):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results  
        url = url_template.format(city, start)
        html = urllib.urlopen(url).read()
        soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")
        results.append(soup)
        pass

# %%
data= []

for i in results:
    for o in i.find_all('div', class_=['row','result']): 
        location = extract_location_from_result(o)
        company = extract_company_from_result(o)
        job = extract_job(o)  
        salary = extract_salary_from_result(o)
        data.append({'location' : location, 'company': company, 'job': job, 'salary':salary})

# %%
data_df = pd.DataFrame(data)
print len(data_df)
# Out:
# 1915

# %%
data_df.to_csv('~/desktop/datascientist.csv' ,mode='a', header=False, encoding = 'utf-8')

# %%
# data_2 = pd.read_csv('~/desktop/datascientist.csv')
# print data_2.shape

# %%
# df = pd.read_csv("http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}")
# df.head()
df_columns = ['company_name', 'title', 'location', 'salary' ]

# %%
import pandas as pd
df = pd.read_csv('~/desktop/datascientist.csv', header = 0, names = df_columns)

# %%
df.head()
# Out:
#               company_name                                title  \
# 1  Syntelli Solutions, Inc                       Data Scientist
# 2              NIT Finance                Senior Data Scientist
# 3              Freddie Mac            Data Science Professional
# 4                    Agile  Data Scientist (USC or GC) (REMOTE)
# 5                      NPR     Data Scientist / Digital Analyst
#
#               location salary
# 1  Charlotte, NC 28277    NaN
# 2         New York, NY    NaN
# 3     McLean, VA 22102    NaN
# 4        Melbourne, FL    NaN
# 5       Washington, DC    NaN

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
print "missing values \n", df.isnull().sum()
# Out:
# missing values
# company_name        7
# title               0
# location            0
# salary          25789
# dtype: int64

# %%
 print "dataframe types \n", df.dtypes     #look for data types of each column
# Out:
# dataframe types
# company_name    object
# title           object
# location        object
# salary          object
# dtype: object

# %%
print 'duplicates \n', df.duplicated().sum() # True if a row is identical to a previous row
# Out:
# duplicates
# 20543

# %%
print 'drop dups \n', df.drop_duplicates(inplace = True)    # Drop the duplicate rows
# Out:
# drop dups
# None

# %%
for item in df:
    print item
    print df[item].nunique()  #number of unique values for each column
# Out:
# company_name
# 2877
# title
# 5317
# location
# 1269
# salary
# 319

# %%
df
# Out:
#                                            company_name  \
# 1                               Syntelli Solutions, Inc
# 2                                           NIT Finance
# 3                                           Freddie Mac
# 4                                                 Agile
# 5                                                   NPR
# 6                                   Axiologic Solutions
# 7                                             BitVoyant
# 8                                              Facebook
# 9                                             DataRobot
# 10                                         Comverge Inc
# 11                                            NxT Level
# 12                                             Grandata
# 13                                    Realogy Corporate
# 14                                              Novetta
# 15                                    MatchPointe Group
# 16                           Partner's Consulting, Inc.
# 17                                     Johnson Controls
# 18                                  Four Seasons Design
# 19                                     Northwell Health
# 20                                                Intel
# 21                                      H3 Technologies
# 22                                  Booz Allen Hamilton
# 23    Northeastern University - Network Science Inst...
# 24                                               Huawei
# 25                                         RedJack, LLC
# 26                          Central Intelligence Agency
# 27                                         AlixPartners
# 28                                                  SAP
# 29                                         Emerge Media
# 30                                               FiveBy
# ...                                                 ...
# 1479                                 The Hexagon Lavish
# 1487                                                NCR
# 1495                                         LexisNexis
# 1520                                 KORE1 Technologies
# 1523                                               KPMG
# 1536                                    Modern Electron
# 1538                                             Indeed
# 1545                                          Wunderman
# 1550                                    ASCII Group LLC
# 1552                                  Novo Nordisk Inc.
# 1553                             SRI Tech Solutions Inc
# 1557                                          Galvanize
# 1559             Fred Hutchinson Cancer Research Center
# 1563                           University of Washington
# 1564                             Seattle Genetics, Inc.
# 1566                           University of Washington
# 1567            University of Washington Medical Center
# 1575                                         CDK Global
# 1592                                           T-Mobile
# 1632                                          Oculus VR
# 1649                                           Spectrum
# 1689                      University of Texas at Austin
# 1694                           Nanometrics Incorporated
# 1733                                Providence Partners
# 1755                                   Cascade Insights
# 1765                 Oregon Health & Science University
# 1790                                   Cascade Insights
# 1800                                               Otak
# 1805                                                HDR
# 1815                               Multnomah County, OR
#
#                                                   title  \
# 1                                        Data Scientist
# 2                                 Senior Data Scientist
# 3                             Data Science Professional
# 4                   Data Scientist (USC or GC) (REMOTE)
# 5                      Data Scientist / Digital Analyst
# 6                            Data Subject Matter Expert
# 7                                 Junior Data Scientist
# 8                               Data Engineer, SocialVR
# 9                               Data Science Evangelist
# 10                                   Jr. Data Scientist
# 11                                       Data Scientist
# 12                                      Data Scientists
# 13                                Junior Data Scientist
# 14                                       Data Scientist
# 15    Principle Scientist, Data Science, System inte...
# 16                                       Data Scientist
# 17          Data Scientist / Software Development Staff
# 18                     Planing Assistant/Data Analysis.
# 19    Data Research Analyst - Office of Chief Nurse ...
# 20                      Machine Learning Systems Intern
# 21                          Entry Level- Data Scientist
# 22                             Data Scientist / Analyst
# 23               Data Visualization Research Specialist
# 24    Intern - Machine Learning for Network Reliability
# 25                           Cleared Jr. Data Scientist
# 26                                       Data Scientist
# 27            Digital Data Scientist Analyst/ Associate
# 28    Data Scientist with ML background for Machine ...
# 29                                       Data Scientist
# 30                  Sr. Data Analyst - Machine Learning
# ...                                                 ...
# 1479             Staff Research Scientist II (PIR Beta)
# 1487  Accounting Policy, Research and Special Projec...
# 1495                      Associate Statistical Modeler
# 1520                       Sr. Associate, Data Analysis
# 1523                                     Data Scientist
# 1536     Materials Engineer - Thermionic / Photocathode
# 1538                          Product Marketing Manager
# 1545                                   Report Developer
# 1550        Data Scientist - Redmond, WA - 9 Months - A
# 1552  Senior Research Scientist - Diabetic Kidney Di...
# 1553                                Cloud Java Engineer
# 1557          Lead Instructor, Principal Data Scientist
# 1559                     Statistical Research Assistant
# 1563                    CONTACT CENTER REPRESENTATIVE 2
# 1564  Director/Associate Director, SERM (Head of PVG...
# 1566                      RESEARCH SCIENTIST/ENGINEER 2
# 1567                      RESEARCH SCIENTIST/ENGINEER 1
# 1575  Accelerator Consultant I - Fixed Operations or...
# 1592           Sr Data Scientist (Information Security)
# 1632  State Estimation and Calibration Scientist, Ph...
# 1649                           Research Analyst - Media
# 1689  Engineering Scientist Associate - R and D Cybe...
# 1694                     Software Engineer (Austin, TX)
# 1733                          Security Research Analyst
# 1755           Market Research Analyst (B2B Technology)
# 1765                            Postdoctoral Researcher
# 1790           Market Research Analyst (B2B Technology)
# 1800  Sr. Water Resources Project Engineer/Project M...
# 1805                                Marketing Assistant
# 1815  Research/Evaluation Analyst 1 (Medical Monitor...
#
#                                     location                      salary
# 1                        Charlotte, NC 28277                         NaN
# 2                               New York, NY                         NaN
# 3                           McLean, VA 22102                         NaN
# 4                              Melbourne, FL                         NaN
# 5                             Washington, DC                         NaN
# 6                             Washington, DC                         NaN
# 7                                Rosslyn, VA                         NaN
# 8                             Menlo Park, CA                         NaN
# 9                             Washington, DC                         NaN
# 10                                Denver, CO                         NaN
# 11                               Seattle, WA  $125,000 - $160,000 a year
# 12                             United States                         NaN
# 13                            Emeryville, CA                         NaN
# 14                          Crystal City, VA                         NaN
# 15                           Santa Clara, CA                         NaN
# 16                                Denver, CO                         NaN
# 17                             Milwaukee, WI                         NaN
# 18                       San Diego, CA 92154                         NaN
# 19                   New Hyde Park, NY 11040                         NaN
# 20                       Hillsboro, OR 97124                         NaN
# 21                        Florence, KY 41042                         NaN
# 22                            Washington, DC                         NaN
# 23                                Boston, MA              $50,000 a year
# 24                           Santa Clara, CA                         NaN
# 25                   Silver Spring, MD 20910                         NaN
# 26                            Washington, DC   $62,338 - $119,794 a year
# 27                             United States                         NaN
# 28                             Palo Alto, CA                         NaN
# 29                         Chicago, IL 60607                         NaN
# 30                               Redmond, WA                         NaN
# ...                                      ...                         ...
# 1479                             Atlanta, GA                         NaN
# 1487                        Duluth, GA 30096                         NaN
# 1495                    Alpharetta, GA 30005                         NaN
# 1520                             Atlanta, GA                         NaN
# 1523                       Seattle, WA 98104                         NaN
# 1536                      Bellevue, WA 98007                         NaN
# 1538                       Seattle, WA 98104                         NaN
# 1545                             Seattle, WA                         NaN
# 1550                             Redmond, WA                         NaN
# 1552                       Seattle, WA 98109                         NaN
# 1553                       Seattle, WA 98104                         NaN
# 1557     Seattle, WA 98104 (First Hill area)                         NaN
# 1559       Seattle, WA 98109 (Westlake area)                         NaN
# 1563                             Seattle, WA     $3,152 - $4,215 a month
# 1564                       Bothell, WA 98021                         NaN
# 1566                             Seattle, WA                         NaN
# 1567                             Seattle, WA                         NaN
# 1575                             Seattle, WA                         NaN
# 1592                            Bellevue, WA                         NaN
# 1632                             Redmond, WA                         NaN
# 1649                        Austin, TX 78716                         NaN
# 1689                              Austin, TX     $5,400 - $6,500 a month
# 1694                              Austin, TX                         NaN
# 1733                              Austin, TX                         NaN
# 1755                      Portland, OR 97266                         NaN
# 1765                            Portland, OR              $45,000 a year
# 1790         Portland, OR 97266 (Lents area)    $70,000 - $90,000 a year
# 1800  Vancouver, WA 98660 (Carter Park area)                         NaN
# 1805      Portland, OR 97204 (Downtown area)                         NaN
# 1815                            Portland, OR    $43,744 - $53,808 a year
#
# [7311 rows x 4 columns]

# %% [markdown]
# Lastly, we need to clean up salary data.
#
# 1. Only a small number of the scraped results have salary information - only these will be used for modeling.
# 1. Some of the salaries are not yearly but hourly or weekly, these will not be useful to us for now
# 1. Some of the entries may be duplicated
# 1. The salaries are given as text and usually with ranges.
#
# #### Find the entries with annual salary entries, by filtering the entries without salaries or salaries that are not yearly (filter those that refer to hour or week). Also, remove duplicate entries

# %%
## YOUR CODE HERE
#create a for loop that goes through each iteration of salary 
# def sal_midpoint(n):
#     sal_range = n.split('-')  # ' - '  #split into lower and higher also remove commas "a year" etc If try and accept statement, look at documentation  
#     numlist = []
# #     not_dash = []
#     for i in sal_range:
#         number = re.search('[\d\,]+',i)
#         number = number.group(0).replace(',','')  #what does this do? why is group here 
#         number = float(number)
#         numlist.append(number)
#     sal_mid = sum(numlist)/len(numlist)
# #     if "-" not in n:
# #         not_dash
#     return sal_mid

# %%
salary2 = df[df.salary.notnull()]

# %%
# def sal_midpoint(n):
#     sal_range = n.split('-')
#     numlist = []

# %%
salary2
# Out:
#                                            company_name  \
# 11                                            NxT Level
# 23    Northeastern University - Network Science Inst...
# 26                          Central Intelligence Agency
# 36                                                 Keyo
# 37                     Computer Enterprises, Inc. (CEI)
# 52                                            NxT Level
# 54                                Workbridge Associates
# 65                                     Barrington James
# 78                                   Platinum Solutions
# 95                                             Genialis
# 99                                      Engage Partners
# 104                          Baylor College of Medicine
# 116                          Baylor College of Medicine
# 130                                     Rice University
# 139                                   Career Evolutions
# 169         Arizona Health Care Cost Containment System
# 183                                    State of Arizona
# 191                                City of Goodyear, AZ
# 201                                         Enodo Score
# 203                                   Huxley Associates
# 212                                  Jobspring Partners
# 220                                               Modis
# 230                                      Liberty Mutual
# 232                             Pathfinder Search Group
# 244                                            Hirewell
# 245                               Workbridge Associates
# 249                               Workbridge Associates
# 255                                  Jobspring Partners
# 256                                  Jobspring Partners
# 257                                 The LaSalle Network
# ...                                                 ...
# 6311                                           Jumpvine
# 6531                                        King County
# 6576                        Seattle Children's Hospital
# 6578                                 Laetus Recruitment
# 6713            University of Washington Medical Center
# 6787            University of Washington Medical Center
# 6790                           University of Washington
# 6882                            Washington State Patrol
# 6914            University of Washington Medical Center
# 6920                           University of Washington
# 7162                      University of Texas at Austin
# 7165                      University of Texas at Austin
# 7295                       Providence Health & Services
# 27                                          The Council
# 54                                    Enterprise Select
# 79                                          Seventhwave
# 413                                  Jobspring Partners
# 418                                  Jobspring Partners
# 422                               Workbridge Associates
# 438                                  Jobspring Partners
# 600                                             Averity
# 661                     Sr Quantitative Finance Analyst
# 686                                  Besen & Associates
# 763                                 Analytic Recruiting
# 1416                       Noell Consulting Group, Inc.
# 1563                           University of Washington
# 1689                      University of Texas at Austin
# 1765                 Oregon Health & Science University
# 1790                                   Cascade Insights
# 1815                               Multnomah County, OR
#
#                                                   title  \
# 11                                       Data Scientist
# 23               Data Visualization Research Specialist
# 26                                       Data Scientist
# 36                                       Data Scientist
# 37                                       Data Scientist
# 52                 Software Engineer - Machine Learning
# 54                                       Data Scientist
# 65              Real World Evidence Statistical Analyst
# 78                                       Data Scientist
# 95                    Bioinformatics Software Developer
# 99                                       Data Scientist
# 104                Quality Assurance Analyst (Research)
# 116                         Flow Cytometry Specialist I
# 130                                  Research Scientist
# 139                                      Data Architect
# 169                    RESEARCH AND STATISTICAL ANALYST
# 183                             AIR QUALITY PLANNER 2-3
# 191                           Budget & Research Analyst
# 201                                       Data Engineer
# 203                                      Data Scientist
# 212                                      Data Scientist
# 220   Sr. Data Scientist // Contract // West Loop Ch...
# 230          Analyst/Senior Analyst, Advanced Analytics
# 232                                       Data Engineer
# 244                                      Data Scientist
# 245                               Senior Data Scientist
# 249                                      Data Scientist
# 255                               Contract Data Science
# 256                           Machine Learning Engineer
# 257                                 Statistical Analyst
# ...                                                 ...
# 6311                       Real Estate Research Analyst
# 6531                                     Student Intern
# 6576                        Predoctoral Research Fellow
# 6578  Software Development Engineer (Back End) (Loca...
# 6713                         ADMINISTRATIVE ASSISTANT A
# 6787                       SUPPLY CHAIN TECHNICIAN LEAD
# 6790                    CONTACT CENTER REPRESENTATIVE 1
# 6882                               SECRETARY SUPERVISOR
# 6914          MEDICAL LABORATORY SCIENTIST-TRAINEE OR 1
# 6920                     MEDICAL LABORATORY SCIENTIST 1
# 7162  Research Associate - Inorganic Sedimentary Geo...
# 7165        Research Associate - R and D Data Scientist
# 7295   Medical Technologist On call- Hematology Testing
# 27                              Data & Research Analyst
# 54                 Principal Data Scientist, Sequencing
# 79                   Energy Efficiency Research Analyst
# 413                                      Data Scientist
# 418                                 Lead Data Scientist
# 422                                      Data Scientist
# 438                            Principal Data Scientist
# 600                 Director of Data Science, Analytics
# 661                     Sr Quantitative Finance Analyst
# 686                      Marketing and Research Analyst
# 763                               Senior Data Scientist
# 1416         Real Estate Research Analyst - Entry Level
# 1563                    CONTACT CENTER REPRESENTATIVE 2
# 1689  Engineering Scientist Associate - R and D Cybe...
# 1765                            Postdoctoral Researcher
# 1790           Market Research Analyst (B2B Technology)
# 1815  Research/Evaluation Analyst 1 (Medical Monitor...
#
#                                           location                      salary
# 11                                     Seattle, WA  $125,000 - $160,000 a year
# 23                                      Boston, MA              $50,000 a year
# 26                                  Washington, DC   $62,338 - $119,794 a year
# 36                                   Palo Alto, CA  $120,000 - $200,000 a year
# 37                                Philadelphia, PA             $160,000 a year
# 52                                     Seattle, WA  $100,000 - $135,000 a year
# 54                                  Washington, DC  $100,000 - $150,000 a year
# 65    New York, NY 10005 (Financial District area)             $110,000 a year
# 78                                     Houston, TX   $80,000 - $120,000 a year
# 95                                     Houston, TX    $50,000 - $80,000 a year
# 99                                     Houston, TX                $120 an hour
# 104                                    Houston, TX              $43,794 a year
# 116                                    Houston, TX              $46,831 a year
# 130                                    Houston, TX    $40,800 - $79,100 a year
# 139                                    Phoenix, AZ             $150,000 a year
# 169                                    Phoenix, AZ    $39,983 - $55,500 a year
# 183                                    Phoenix, AZ    $45,000 - $77,000 a year
# 191                                   Goodyear, AZ    $63,696 - $94,557 a year
# 201                                    Chicago, IL    $70,000 - $90,000 a year
# 203                                    Chicago, IL             $100,000 a year
# 212                                    Chicago, IL  $120,000 - $140,000 a year
# 220        Chicago, IL 60661 (Near West Side area)          $85 - $110 an hour
# 230                                    Chicago, IL   $73,300 - $114,900 a year
# 232                                    Chicago, IL           $50 - $70 an hour
# 244                                   Evanston, IL             $150,000 a year
# 245                                    Chicago, IL             $130,000 a year
# 249                                    Chicago, IL             $125,000 a year
# 255                                    Chicago, IL           $50 - $70 an hour
# 256                                    Chicago, IL  $120,000 - $150,000 a year
# 257                  Chicago, IL 60601 (Loop area)              $80,000 a year
# ...                                            ...                         ...
# 6311                                   Roswell, GA              $55,000 a year
# 6531                                   Seattle, WA     $13.30 - $16.85 an hour
# 6576             Seattle, WA 98101 (Downtown area)    $36,700 - $55,000 a year
# 6578                                   Seattle, WA  $120,000 - $150,000 a year
# 6713                                   Seattle, WA     $2,867 - $3,818 a month
# 6787                                   Seattle, WA     $2,910 - $3,879 a month
# 6790                                   Seattle, WA     $3,077 - $4,113 a month
# 6882                                 Snohomish, WA     $2,792 - $3,627 a month
# 6914                                   Seattle, WA     $4,495 - $6,626 a month
# 6920                                   Seattle, WA     $4,319 - $6,371 a month
# 7162                                    Austin, TX     $6,250 - $8,333 a month
# 7165                                    Austin, TX     $7,083 - $9,166 a month
# 7295             Portland, OR 97240 (Hosford area)                           0
# 27                                  Washington, DC    $80,000 - $85,000 a year
# 54                           Santa Clara, CA 95050             $150,000 a year
# 79                               Madison, WI 53705           $26 - $42 an hour
# 413                  Chicago, IL 60603 (Loop area)             $120,000 a year
# 418                                    Chicago, IL  $100,000 - $150,000 a year
# 422                                    Chicago, IL                 $65 an hour
# 438                                    Chicago, IL  $120,000 - $160,000 a year
# 600                              San Francisco, CA  $175,000 - $250,000 a year
# 661                                   New York, NY  $100,000 - $180,000 a year
# 686                                   New York, NY           $18 - $20 an hour
# 763              New York, NY 10017 (Midtown area)             $160,000 a year
# 1416                                   Atlanta, GA    $50,000 - $60,000 a year
# 1563                                   Seattle, WA     $3,152 - $4,215 a month
# 1689                                    Austin, TX     $5,400 - $6,500 a month
# 1765                                  Portland, OR              $45,000 a year
# 1790               Portland, OR 97266 (Lents area)    $70,000 - $90,000 a year
# 1815                                  Portland, OR    $43,744 - $53,808 a year
#
# [501 rows x 4 columns]

# %%
type(salary2)
# Out:
# pandas.core.frame.DataFrame

# %%
# salary2.salary.str.replace('[\,$]', '')
# Out:
# 11      $125,000 - $160,000 a year
# 23                  $50,000 a year
# 26       $62,338 - $119,794 a year
# 36      $120,000 - $200,000 a year
# 37                 $160,000 a year
# 52      $100,000 - $135,000 a year
# 54      $100,000 - $150,000 a year
# 65                 $110,000 a year
# 78       $80,000 - $120,000 a year
# 95        $50,000 - $80,000 a year
# 99                    $120 an hour
# 104                 $43,794 a year
# 116                 $46,831 a year
# 130       $40,800 - $79,100 a year
# 139                $150,000 a year
# 169       $39,983 - $55,500 a year
# 183       $45,000 - $77,000 a year
# 191       $63,696 - $94,557 a year
# 201       $70,000 - $90,000 a year
# 203                $100,000 a year
# 212     $120,000 - $140,000 a year
# 220             $85 - $110 an hour
# 230      $73,300 - $114,900 a year
# 232              $50 - $70 an hour
# 244                $150,000 a year
# 245                $130,000 a year
# 249                $125,000 a year
# 255              $50 - $70 an hour
# 256     $120,000 - $150,000 a year
# 257                 $80,000 a year
#                    ...
# 6311                $55,000 a year
# 6531       $13.30 - $16.85 an hour
# 6576      $36,700 - $55,000 a year
# 6578    $120,000 - $150,000 a year
# 6713       $2,867 - $3,818 a month
# 6787       $2,910 - $3,879 a month
# 6790       $3,077 - $4,113 a month
# 6882       $2,792 - $3,627 a month
# 6914       $4,495 - $6,626 a month
# 6920       $4,319 - $6,371 a month
# 7162       $6,250 - $8,333 a month
# 7165       $7,083 - $9,166 a month
# 7295                             0
# 27        $80,000 - $85,000 a year
# 54                 $150,000 a year
# 79               $26 - $42 an hour
# 413                $120,000 a year
# 418     $100,000 - $150,000 a year
# 422                    $65 an hour
# 438     $120,000 - $160,000 a year
# 600     $175,000 - $250,000 a year
# 661     $100,000 - $180,000 a year
# 686              $18 - $20 an hour
# 763                $160,000 a year
# 1416      $50,000 - $60,000 a year
# 1563       $3,152 - $4,215 a month
# 1689       $5,400 - $6,500 a month
# 1765                $45,000 a year
# 1790      $70,000 - $90,000 a year
# 1815      $43,744 - $53,808 a year
# Name: salary, dtype: object

# %%
 salary2.head(15)
# Out:
#                                           company_name  \
# 11                                           NxT Level
# 23   Northeastern University - Network Science Inst...
# 26                         Central Intelligence Agency
# 36                                                Keyo
# 37                    Computer Enterprises, Inc. (CEI)
# 52                                           NxT Level
# 54                               Workbridge Associates
# 65                                    Barrington James
# 78                                  Platinum Solutions
# 95                                            Genialis
# 99                                     Engage Partners
# 104                         Baylor College of Medicine
# 116                         Baylor College of Medicine
# 130                                    Rice University
# 139                                  Career Evolutions
#
#                                        title  \
# 11                            Data Scientist
# 23    Data Visualization Research Specialist
# 26                            Data Scientist
# 36                            Data Scientist
# 37                            Data Scientist
# 52      Software Engineer - Machine Learning
# 54                            Data Scientist
# 65   Real World Evidence Statistical Analyst
# 78                            Data Scientist
# 95         Bioinformatics Software Developer
# 99                            Data Scientist
# 104     Quality Assurance Analyst (Research)
# 116              Flow Cytometry Specialist I
# 130                       Research Scientist
# 139                           Data Architect
#
#                                          location                      salary
# 11                                    Seattle, WA  $125,000 - $160,000 a year
# 23                                     Boston, MA              $50,000 a year
# 26                                 Washington, DC   $62,338 - $119,794 a year
# 36                                  Palo Alto, CA  $120,000 - $200,000 a year
# 37                               Philadelphia, PA             $160,000 a year
# 52                                    Seattle, WA  $100,000 - $135,000 a year
# 54                                 Washington, DC  $100,000 - $150,000 a year
# 65   New York, NY 10005 (Financial District area)             $110,000 a year
# 78                                    Houston, TX   $80,000 - $120,000 a year
# 95                                    Houston, TX    $50,000 - $80,000 a year
# 99                                    Houston, TX                $120 an hour
# 104                                   Houston, TX              $43,794 a year
# 116                                   Houston, TX              $46,831 a year
# 130                                   Houston, TX    $40,800 - $79,100 a year
# 139                                   Phoenix, AZ             $150,000 a year

# %%
# for i,v in df.iterrows():
#     try:
#         df.loc[i,'estimate'] = sal_midpoint(v['salary'])
#     except:
#         df.loc[i,'estimate']= np.nan

# %%
df
# Out:
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11      125,000 - 160,000 a year
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                 50,000 a year
# 24                           NaN
# 25                           NaN
# 26       62,338 - 119,794 a year
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
#                   ...
# 1479                         NaN
# 1487                         NaN
# 1495                         NaN
# 1520                         NaN
# 1523                         NaN
# 1536                         NaN
# 1538                         NaN
# 1545                         NaN
# 1550                         NaN
# 1552                         NaN
# 1553                         NaN
# 1557                         NaN
# 1559                         NaN
# 1563       3,152 - 4,215 a month
# 1564                         NaN
# 1566                         NaN
# 1567                         NaN
# 1575                         NaN
# 1592                         NaN
# 1632                         NaN
# 1649                         NaN
# 1689       5,400 - 6,500 a month
# 1694                         NaN
# 1733                         NaN
# 1755                         NaN
# 1765               45,000 a year
# 1790      70,000 - 90,000 a year
# 1800                         NaN
# 1805                         NaN
# 1815      43,744 - 53,808 a year
# Name: salary, dtype: object

# %%
# sal_revised = sal_revised[sal_revised['salary'].str.contains("month", na=False) == False]
# sal_revised = sal_revised[sal_revised['salary'].str.contains("hour", na=False) == False]
# sal_revised = sal_revised[sal_revised['salary'].str.contains("week", na=False) == False]

# %%
yearly = salary2[salary2.salary.str.contains('year')]

# %%
yearly.head(15)
# Out:
#                                           company_name  \
# 11                                           NxT Level
# 23   Northeastern University - Network Science Inst...
# 26                         Central Intelligence Agency
# 36                                                Keyo
# 37                    Computer Enterprises, Inc. (CEI)
# 52                                           NxT Level
# 54                               Workbridge Associates
# 65                                    Barrington James
# 78                                  Platinum Solutions
# 95                                            Genialis
# 104                         Baylor College of Medicine
# 116                         Baylor College of Medicine
# 130                                    Rice University
# 139                                  Career Evolutions
# 169        Arizona Health Care Cost Containment System
#
#                                        title  \
# 11                            Data Scientist
# 23    Data Visualization Research Specialist
# 26                            Data Scientist
# 36                            Data Scientist
# 37                            Data Scientist
# 52      Software Engineer - Machine Learning
# 54                            Data Scientist
# 65   Real World Evidence Statistical Analyst
# 78                            Data Scientist
# 95         Bioinformatics Software Developer
# 104     Quality Assurance Analyst (Research)
# 116              Flow Cytometry Specialist I
# 130                       Research Scientist
# 139                           Data Architect
# 169         RESEARCH AND STATISTICAL ANALYST
#
#                                          location                      salary
# 11                                    Seattle, WA  $125,000 - $160,000 a year
# 23                                     Boston, MA              $50,000 a year
# 26                                 Washington, DC   $62,338 - $119,794 a year
# 36                                  Palo Alto, CA  $120,000 - $200,000 a year
# 37                               Philadelphia, PA             $160,000 a year
# 52                                    Seattle, WA  $100,000 - $135,000 a year
# 54                                 Washington, DC  $100,000 - $150,000 a year
# 65   New York, NY 10005 (Financial District area)             $110,000 a year
# 78                                    Houston, TX   $80,000 - $120,000 a year
# 95                                    Houston, TX    $50,000 - $80,000 a year
# 104                                   Houston, TX              $43,794 a year
# 116                                   Houston, TX              $46,831 a year
# 130                                   Houston, TX    $40,800 - $79,100 a year
# 139                                   Phoenix, AZ             $150,000 a year
# 169                                   Phoenix, AZ    $39,983 - $55,500 a year

# %%
yearly['salary'] = yearly.salary.str.replace('[\,$]', '')
# Out:
# /Users/robwatkins/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
yearly['salary'] = yearly.salary.str.replace('a year', '')
# Out:
# /Users/robwatkins/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
yearly.head(20)
# Out:
#                                           company_name  \
# 11                                           NxT Level
# 23   Northeastern University - Network Science Inst...
# 26                         Central Intelligence Agency
# 36                                                Keyo
# 37                    Computer Enterprises, Inc. (CEI)
# 52                                           NxT Level
# 54                               Workbridge Associates
# 65                                    Barrington James
# 78                                  Platinum Solutions
# 95                                            Genialis
# 104                         Baylor College of Medicine
# 116                         Baylor College of Medicine
# 130                                    Rice University
# 139                                  Career Evolutions
# 169        Arizona Health Care Cost Containment System
# 183                                   State of Arizona
# 191                               City of Goodyear, AZ
# 201                                        Enodo Score
# 203                                  Huxley Associates
# 212                                 Jobspring Partners
#
#                                        title  \
# 11                            Data Scientist
# 23    Data Visualization Research Specialist
# 26                            Data Scientist
# 36                            Data Scientist
# 37                            Data Scientist
# 52      Software Engineer - Machine Learning
# 54                            Data Scientist
# 65   Real World Evidence Statistical Analyst
# 78                            Data Scientist
# 95         Bioinformatics Software Developer
# 104     Quality Assurance Analyst (Research)
# 116              Flow Cytometry Specialist I
# 130                       Research Scientist
# 139                           Data Architect
# 169         RESEARCH AND STATISTICAL ANALYST
# 183                  AIR QUALITY PLANNER 2-3
# 191                Budget & Research Analyst
# 201                            Data Engineer
# 203                           Data Scientist
# 212                           Data Scientist
#
#                                          location            salary
# 11                                    Seattle, WA  125000 - 160000
# 23                                     Boston, MA            50000
# 26                                 Washington, DC   62338 - 119794
# 36                                  Palo Alto, CA  120000 - 200000
# 37                               Philadelphia, PA           160000
# 52                                    Seattle, WA  100000 - 135000
# 54                                 Washington, DC  100000 - 150000
# 65   New York, NY 10005 (Financial District area)           110000
# 78                                    Houston, TX   80000 - 120000
# 95                                    Houston, TX    50000 - 80000
# 104                                   Houston, TX            43794
# 116                                   Houston, TX            46831
# 130                                   Houston, TX    40800 - 79100
# 139                                   Phoenix, AZ           150000
# 169                                   Phoenix, AZ    39983 - 55500
# 183                                   Phoenix, AZ    45000 - 77000
# 191                                  Goodyear, AZ    63696 - 94557
# 201                                   Chicago, IL    70000 - 90000
# 203                                   Chicago, IL           100000
# 212                                   Chicago, IL  120000 - 140000

# %%
def sal_midpoint(n):
    sal_range = n.split('-')  # ' - '  #split into lower and higher also remove commas "a year" etc If try and accept statement, look at documentation  
    numlist = []
    for i in sal_range:
        number = re.search('[\d\,]+',i)
        number = number.group(0).replace(',','')  #what does this do? why is group here 
        number = float(number)
        numlist.append(number)
    sal_mid = sum(numlist)/len(numlist)
    return sal_mid

# %%
for i,v in yearly.iterrows():
    try:
        yearly.loc[i,'estimate'] = sal_midpoint(v['salary'])
    except:
        yearly.loc[i,'estimate']= np.nan
# Out:
# /Users/robwatkins/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/robwatkins/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
yearly.head(20)
# Out:
#                                           company_name  \
# 11                                           NxT Level
# 23   Northeastern University - Network Science Inst...
# 26                         Central Intelligence Agency
# 36                                                Keyo
# 37                    Computer Enterprises, Inc. (CEI)
# 52                                           NxT Level
# 54                               Workbridge Associates
# 65                                    Barrington James
# 78                                  Platinum Solutions
# 95                                            Genialis
# 104                         Baylor College of Medicine
# 116                         Baylor College of Medicine
# 130                                    Rice University
# 139                                  Career Evolutions
# 169        Arizona Health Care Cost Containment System
# 183                                   State of Arizona
# 191                               City of Goodyear, AZ
# 201                                        Enodo Score
# 203                                  Huxley Associates
# 212                                 Jobspring Partners
#
#                                        title  \
# 11                            Data Scientist
# 23    Data Visualization Research Specialist
# 26                            Data Scientist
# 36                            Data Scientist
# 37                            Data Scientist
# 52      Software Engineer - Machine Learning
# 54                            Data Scientist
# 65   Real World Evidence Statistical Analyst
# 78                            Data Scientist
# 95         Bioinformatics Software Developer
# 104     Quality Assurance Analyst (Research)
# 116              Flow Cytometry Specialist I
# 130                       Research Scientist
# 139                           Data Architect
# 169         RESEARCH AND STATISTICAL ANALYST
# 183                  AIR QUALITY PLANNER 2-3
# 191                Budget & Research Analyst
# 201                            Data Engineer
# 203                           Data Scientist
# 212                           Data Scientist
#
#                                          location            salary  estimate
# 11                                    Seattle, WA  125000 - 160000   142500.0
# 23                                     Boston, MA            50000    50000.0
# 26                                 Washington, DC   62338 - 119794    91066.0
# 36                                  Palo Alto, CA  120000 - 200000   160000.0
# 37                               Philadelphia, PA           160000   160000.0
# 52                                    Seattle, WA  100000 - 135000   117500.0
# 54                                 Washington, DC  100000 - 150000   150000.0
# 65   New York, NY 10005 (Financial District area)           110000   110000.0
# 78                                    Houston, TX   80000 - 120000   100000.0
# 95                                    Houston, TX    50000 - 80000    65000.0
# 104                                   Houston, TX            43794    43794.0
# 116                                   Houston, TX            46831    46831.0
# 130                                   Houston, TX    40800 - 79100    59950.0
# 139                                   Phoenix, AZ           150000   150000.0
# 169                                   Phoenix, AZ    39983 - 55500    47741.5
# 183                                   Phoenix, AZ    45000 - 77000    61000.0
# 191                                  Goodyear, AZ    63696 - 94557    79126.5
# 201                                   Chicago, IL    70000 - 90000    80000.0
# 203                                   Chicago, IL           100000   100000.0
# 212                                   Chicago, IL  120000 - 140000   130000.0

# %%
yearly.shape
# Out:
# (353, 5)

# %%
yearly['median'] = np.median(estimate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-309-eebe64fa8799> in <module>()
# ----> 1 yearly['median'] = np.median(estimate)
#
# NameError: name 'estimate' is not defined

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
Export to csv
sal_revised = df.dropna(subset=['sal_update']
# Out:
#   File "<ipython-input-149-a2be7785a427>", line 2
#     sal_revised = df.dropna(subset=['sal_update']
#                                                  ^
# SyntaxError: invalid syntax

# %%
# #sal_update shows average score of intervals between salary 

# sal_revised = sal_revised[sal_revised['salary'].str.contains("month", na=False) == False]
# sal_revised = sal_revised[sal_revised['salary'].str.contains("hour", na=False) == False]
# sal_revised = sal_revised[sal_revised['salary'].str.contains("week", na=False) == False]

# %%
# sal_revised4 = df[df['salary'].notnull()]
# sal_revised3 = sal_revised4[sal_revised4['salary'].str.contains("year")]
# # sal_revised3 = df[df['salary'].str.contains("hour", na=False) == False]
# # sal_revised3 = df[df['salary'].str.contains("week", na=False) == False]
# sal_revised3.drop('estimate', inplace = True)

# %%
# sal_revised3

# %% [markdown]
# ## Predicting salaries using Random Forests + Another Classifier

# %%
# sal_revised1 = sal_revised.sal_update.str.contains('year')

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)
#
# We could also perform Linear Regression (or any regression) to predict the salary value here. Instead, we are going to convert this into a _binary_ classification problem, by predicting two classes, HIGH vs LOW salary.
#
# While performing regression may be better, performing classification may help remove some of the noise of the extreme salaries. We don't _have_ to choose the `median` as the splitting point - we could also split on the 75th percentile or any other reasonable breaking point.
#
# In fact, the ideal scenario may be to predict many levels of salaries,

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Random Forest model to predict High/Low salary using Sklearn. Start by ONLY using the location as a feature.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Random Forest with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with the new variables
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy of the model.

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate your models using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE
